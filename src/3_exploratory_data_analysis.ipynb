# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
DATASET_PATH = '../data-new/data-without-troponina.csv'
df = pd.read_csv(DATASET_PATH)

# %% [markdown]
# Vemos los primeros estadísticos de las distribuciones de las variables:

# %%
df.describe()
# Out:
#               EDAD         SEX0          HTA          DBT          DLP  \
# count  1818.000000  1818.000000  1818.000000  1818.000000  1818.000000
# mean     66.449945     0.704620     0.663916     0.196370     0.547305
# std      12.313550     0.456339     0.472498     0.397361     0.497894
# min      25.000000     0.000000     0.000000     0.000000     0.000000
# 25%      58.000000     0.000000     0.000000     0.000000     0.000000
# 50%      66.000000     1.000000     1.000000     0.000000     1.000000
# 75%      76.000000     1.000000     1.000000     0.000000     1.000000
# max     100.000000     1.000000     1.000000     1.000000     1.000000
#
#              TABAQ  ANTEC IAM / Angina inestable  ANTEC BY PASS    ANTEC ATC  \
# count  1818.000000                   1818.000000    1818.000000  1818.000000
# mean      0.350385                      0.265127       0.072607     0.186469
# std       0.477222                      0.441522       0.259562     0.389592
# min       0.000000                      0.000000       0.000000     0.000000
# 25%       0.000000                      0.000000       0.000000     0.000000
# 50%       0.000000                      0.000000       0.000000     0.000000
# 75%       1.000000                      1.000000       0.000000     0.000000
# max       1.000000                      1.000000       1.000000     1.000000
#
#          ANTEC ACE  ...      TROMBOL          CRM  MUERTE HOSP  \
# count  1818.000000  ...  1817.000000  1815.000000  1818.000000
# mean      0.039054  ...     0.008255     0.080441     0.035204
# std       0.193777  ...     0.090508     0.272049     0.184345
# min       0.000000  ...     0.000000     0.000000     0.000000
# 25%       0.000000  ...     0.000000     0.000000     0.000000
# 50%       0.000000  ...     0.000000     0.000000     0.000000
# 75%       0.000000  ...     0.000000     0.000000     0.000000
# max       1.000000  ...     1.000000     1.000000     1.000000
#
#        IAM HOSP(SI INTERNO POR ANGINA) O REIAM       APIAM  Peor KILLIP  \
# count                              1815.000000  1815.00000  1818.000000
# mean                                  0.014876     0.01157     1.073707
# std                                   0.121090     0.10697     0.403700
# min                                   0.000000     0.00000     0.000000
# 25%                                   0.000000     0.00000     1.000000
# 50%                                   0.000000     0.00000     1.000000
# 75%                                   0.000000     0.00000     1.000000
# max                                   1.000000     1.00000     4.000000
#
#        ANGINA REFRACT o RECURR      ACV/TIA  SANGRADO MAYOR*  I RENAL AGUDA
# count              1815.000000  1814.000000      1814.000000    1816.000000
# mean                  0.034711     0.002756         0.015436       0.055617
# std                   0.183097     0.052443         0.123311       0.229243
# min                   0.000000     0.000000         0.000000       0.000000
# 25%                   0.000000     0.000000         0.000000       0.000000
# 50%                   0.000000     0.000000         0.000000       0.000000
# 75%                   0.000000     0.000000         0.000000       0.000000
# max                   1.000000     1.000000         1.000000       1.000000
#
# [8 rows x 73 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1818 entries, 0 to 1817
# Data columns (total 73 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   EDAD                                     1818 non-null   int64
#  1   SEX0                                     1818 non-null   int64
#  2   HTA                                      1818 non-null   int64
#  3   DBT                                      1818 non-null   int64
#  4   DLP                                      1818 non-null   int64
#  5   TABAQ                                    1818 non-null   int64
#  6   ANTEC IAM / Angina inestable             1818 non-null   int64
#  7   ANTEC BY PASS                            1818 non-null   int64
#  8   ANTEC ATC                                1818 non-null   int64
#  9   ANTEC ACE                                1818 non-null   int64
#  10  ANTEC INS RENAL                          1818 non-null   int64
#  11  ACV TIA PREV                             1818 non-null   int64
#  12  EPOC                                     1818 non-null   int64
#  13  CLAUD ITTE                               1818 non-null   int64
#  14  BB PREV                                  1818 non-null   int64
#  15   IECA/AT2  PREV                          1818 non-null   int64
#  16  B CA PREV                                1818 non-null   int64
#  17  AAS PREV                                 1818 non-null   int64
#  18  HIPOGLUCEMIANTES                         1818 non-null   int64
#  19  DIURETICOS                               1818 non-null   int64
#  20  INSULINA                                 1818 non-null   int64
#  21  PESO Kg                                  1725 non-null   float64
#  22  ALTURA cm                                1698 non-null   float64
#  23  ECG INFRA ST                             1818 non-null   int64
#  24  ECG SUPRA ST                             1818 non-null   int64
#  25  ECG INV T                                1818 non-null   int64
#  26  BRI                                      1817 non-null   float64
#  27  BRD                                      1818 non-null   int64
#  28  ECG MCP                                  1818 non-null   int64
#  29  ECG FA                                   1817 non-null   float64
#  30  tropst                                   1816 non-null   float64
#  31  TnT Ultrasensible                        1818 non-null   int64
#  32  Elevacion troponina T                    1818 non-null   int64
#  33  CREAT                                    1808 non-null   float64
#  34  GLUCEMIA INGR                            1735 non-null   float64
#  35  GB                                       1752 non-null   float64
#  36  TAS INGRESO                              1806 non-null   float64
#  37  FC INGRESO                               1807 non-null   float64
#  38  KILLIP Ingreso                           1818 non-null   int64
#  39  AAS                                      1818 non-null   int64
#  40  BB                                       1800 non-null   float64
#  41  IECA                                     1818 non-null   int64
#  42  AT2                                      1817 non-null   float64
#  43  Clopi - prasu - tica                     1818 non-null   int64
#  44  HEP sc o iv                              1818 non-null   int64
#  45  IIb IIIa                                 1818 non-null   int64
#  46  B CA                                     1817 non-null   float64
#  47  ESTATINAS                                1818 non-null   int64
#  48  HIPOGLUC METFORM                         1817 non-null   float64
#  49  HIPOGL SULFAN                            1818 non-null   int64
#  50  HIPOGL GLITAZ                            1814 non-null   float64
#  51  INSULINA.1                               1817 non-null   float64
#  52  INS + HIPOGL                             1817 non-null   float64
#  53  INOTROPICOS                              1800 non-null   float64
#  54  FUNCION VENTRICULAR IZQ                  1810 non-null   float64
#  55  DIAGNOSTICO                              1817 non-null   float64
#  56  PRUEBA FUNC.                             1818 non-null   int64
#  57  PRUEBA FUNC DE ALTO RIESGO               1817 non-null   float64
#  58  CCG                                      1818 non-null   int64
#  59  TRONCO                                   1817 non-null   float64
#  60  NUMERO VASOS                             1816 non-null   float64
#  61  ATC PRIMARIA                             1818 non-null   int64
#  62  ATC INTRAHOSP                            1818 non-null   int64
#  63  TROMBOL                                  1817 non-null   float64
#  64  CRM                                      1815 non-null   float64
#  65  MUERTE HOSP                              1818 non-null   int64
#  66  IAM HOSP(SI INTERNO POR ANGINA) O REIAM  1815 non-null   float64
#  67  APIAM                                    1815 non-null   float64
#  68  Peor KILLIP                              1818 non-null   int64
#  69  ANGINA REFRACT o RECURR                  1815 non-null   float64
#  70   ACV/TIA                                 1814 non-null   float64
#  71  SANGRADO MAYOR*                          1814 non-null   float64
#  72  I RENAL AGUDA                            1816 non-null   float64
# dtypes: float64(31), int64(42)
# memory usage: 1.0 MB

# %%
# Asumptions
NUMERICAL_FEATURES = ['EDAD','PESO Kg', 'ALTURA cm', 'CREAT', 'GLUCEMIA INGR', 'GB', 'TAS INGRESO', 'FC INGRESO']
NUMERICAL_CONTINOUS = NUMERICAL_FEATURES

CATEGORICAL_MULTI_CLASS_FEATURES = ['KILLIP Ingreso', 'FUNCION VENTRICULAR IZQ', 'DIAGNOSTICO', 'NUMERO VASOS', 'Peor KILLIP']
CATEGORICAL_BINARY_FEATURES = ['NUMERO VASOS', 'SEX0', 'HTA', 'DBT', 'DLP', 'TABAQ', 'ANTEC IAM / Angina inestable', 'ANTEC BY PASS', 'ANTEC ATC', 'ANTEC ACE', 'ANTEC INS RENAL', 'ACV TIA PREV', 'EPOC', 'CLAUD ITTE', 'BB PREV', ' IECA/AT2  PREV', 'B CA PREV', 'AAS PREV', 'HIPOGLUCEMIANTES', 'DIURETICOS', 'INSULINA', 'ECG INFRA ST', 'ECG SUPRA ST', 'ECG INV T', 'BRI', 'BRD', 'ECG MCP', 'ECG FA', 'tropst', 'TnT Ultrasensible', 'Elevacion troponina T', 'AAS', 'BB', 'IECA', 'AT2', 'Clopi - prasu - tica', 'HEP sc o iv', 'IIb IIIa', 'B CA', 'ESTATINAS', 'HIPOGLUC METFORM', 'HIPOGL SULFAN', 'HIPOGL GLITAZ', 'INSULINA', 'INS + HIPOGL', 'INOTROPICOS', 'PRUEBA FUNC.', 'PRUEBA FUNC DE ALTO RIESGO', 'CCG', 'TRONCO', 'ATC PRIMARIA', 'ATC INTRAHOSP', 'TROMBOL', 'CRM', 'IAM HOSP(SI INTERNO POR ANGINA) O REIAM', 'APIAM', 'ANGINA REFRACT o RECURR', ' ACV/TIA', 'SANGRADO MAYOR*', 'I RENAL AGUDA']

CATEGORY_FEATURES = CATEGORICAL_BINARY_FEATURES + CATEGORICAL_MULTI_CLASS_FEATURES

TARGET = "MUERTE HOSP"

# %% [markdown]
# Continuamos analizando las variables realizando histogramas, qq-plots y box-plots para ver distribuciones y outliers de las variables numéricas:

# %%
from utils import outlier_diagnostic_plots

# %%
for column in df[NUMERICAL_CONTINOUS].columns:
    outlier_diagnostic_plots(df, column)

# %%
# Determinar el número de filas necesario
num_cols = 3
num_rows = math.ceil(len(CATEGORY_FEATURES) / num_cols)

# Crear una figura con subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))

# Aplanar los ejes para iterar fácilmente si hay más de una fila
axes = axes.flatten()

# Crear un gráfico de barra para cada columna categórica
for i, col in enumerate(CATEGORY_FEATURES):
    sns.countplot(x=df[col], ax=axes[i])
    axes[i].set_title(f'Gráfico de barra de {col}')

# Eliminar cualquier subplot sobrante
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajustar el layout para que no se sobrepongan los gráficos
plt.tight_layout()

# Mostrar la figura
plt.show()

# %%
frecuencias_target = df[TARGET].value_counts()

df_frecuencias = frecuencias_target.reset_index()
df_frecuencias.columns = ['MUERTE HOSP', 'Frecuencia']

sns.barplot(x='MUERTE HOSP', y='Frecuencia', data=df_frecuencias)
plt.show()

# %% [markdown]
# Vemos que las clases de la variable target estan muy desbalanceadas.

# %% [markdown]
# Finalmente calculamos las matrices de correlacion de Pearson y Spearman:

# %%
fig,ax = plt.subplots(1, 2,figsize=(20, 8))

# PEARSON CORRELATION MATRIX
pearson_corr_matrix = df[NUMERICAL_FEATURES].corr(method='pearson')
sns.set(font_scale=1.2)
sns.heatmap(pearson_corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True, ax=ax[0])
ax[0].grid(False)
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45, ha='right')
ax[0].set_title("Pearson Correlation Matrix")

# SPEARMAN CORRELATION MATRIX
spearman_corr_matrix = df[NUMERICAL_FEATURES].corr(method='spearman')
sns.set(font_scale=1.2)
sns.heatmap(spearman_corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True, ax=ax[1])
ax[1].grid(False)
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45, ha='right')
ax[1].set_title("Spearman Correlation Matrix")

plt.show()
